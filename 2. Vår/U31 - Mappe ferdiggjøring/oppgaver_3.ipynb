# %%
## Oppgave 3-13

while True:                                            # Dine kommentarer her
    try:                                               # Prøver funksjonen under
        alder = int(input("Hvor gammel er du? "))      # Setter alder til en input av et heltall
        break                                          # Om alderen fungerer, går den ut av loopen
    except:                                            # Om den ikke funker, printer den koden under
        print("Ugyldig input. Alder må være et tall.") #
år = 2024                                              # Setter år til 2024
fødselsår = år - alder                                 # setter fødselsår som differansen av alder og år
print(f"Du er født i {fødselsår}")                     # Printer fødselsåret.

# %%
## Oppgave 3-14

navn = input("Skriv navnet ditt: ")
 
navn_l = navn.split(" ")
 
if len(navn_l) < 2:
    navn = input("du trenger to navn minst: ")
else:
    print(f"@{navn_l[0].lower()}{navn_l[-1]}")
# Out:
# @kasåsaleh

# %%
def er_skuddår(årstall: int):
    if årstall % 4 == 0:
        if årstall % 100 == 0:
            if årstall % 400 == 0:
                return True
            else:
                return False
        else:
            return True
    return False
 
# Tester:
skuddår = [1704, 1708, 1712, 1716, 1720, 1724, 1728, 1732, 1736, 1740, 1744, 1748, 1752, 1756, 1760, 1764, 1768, 1772, 1776, 1780, 1784, 1788, 1792, 1796, 1804, 1808, 1812, 1816, 1820, 1824, 1828, 1832, 1836, 1840, 1844, 1848, 1852, 1856, 1860, 1864, 1868, 1872, 1876, 1880, 1884, 1888, 1892, 1896, 1904, 1908, 1912, 1916, 1920, 1924, 1928, 1932, 1936, 1940, 1944, 1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016, 2020, 2024, 2028, 2032, 2036, 2040, 2044, 2048, 2052, 2056, 2060, 2064, 2068, 2072, 2076, 2080, 2084, 2088, 2092, 2096, 2104, 2108, 2112, 2116, 2120, 2124, 2128, 2132, 2136, 2140, 2144, 2148, 2152, 2156, 2160, 2164, 2168, 2172, 2176, 2180, 2184, 2188, 2192, 2196]
for år in range(1704, 2197):
    if år in skuddår:
        assert er_skuddår(år) == True
    else:
        assert er_skuddår(år) == False   


#  Kan sjekke
# for år in skuddår:
#     if er_skuddår(år) == True:
#         print(f"{år} er et skuddår")
# Out:
# 1704 er et skuddår
# 1708 er et skuddår
# 1712 er et skuddår
# 1716 er et skuddår
# 1720 er et skuddår
# 1724 er et skuddår
# 1728 er et skuddår
# 1732 er et skuddår
# 1736 er et skuddår
# 1740 er et skuddår
# 1744 er et skuddår
# 1748 er et skuddår
# 1752 er et skuddår
# 1756 er et skuddår
# 1760 er et skuddår
# 1764 er et skuddår
# 1768 er et skuddår
# 1772 er et skuddår
# 1776 er et skuddår
